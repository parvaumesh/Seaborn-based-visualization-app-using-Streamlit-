# %%
# %pip install --upgrade seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting seaborn
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\dell\appdata\roaming\python\python313\site-packages (from seaborn) (2.2.4)
# Requirement already satisfied: pandas>=1.2 in c:\users\dell\appdata\roaming\python\python313\site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\dell\appdata\roaming\python\python313\site-packages (from seaborn) (3.10.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\dell\appdata\roaming\python\python313\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\dell\appdata\roaming\python\python313\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\dell\appdata\roaming\python\python313\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\dell\appdata\roaming\python\python313\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\dell\appdata\roaming\python\python313\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\dell\appdata\roaming\python\python313\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\dell\appdata\roaming\python\python313\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\dell\appdata\roaming\python\python313\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dell\appdata\roaming\python\python313\site-packages (from pandas>=1.2->seaborn) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\dell\appdata\roaming\python\python313\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\dell\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
sns.get_dataset_names() # it will give in build data sets
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
titanic = sns.load_dataset("titanic")
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.set_theme(style="darkgrid")

# %%
tips.to_csv("tips_dataset.csv",index= False) # the data set(EXCEL) will store in your device

# %%
# we will get the path where currently it's working location 
import os
os.getcwd()
# Out:
# 'c:\\Users\\DELL\\NIT\\Workshop'

# %%
plt.figure(figsize=(8,6))

# %% [markdown]
# # 1. Scatterplot

# %%
sns.scatterplot(data=tips, x="total_bill", y="tip",hue="time",size="size",palette="deep")
plt.title("Scatterplot of Total bill vs Tip")
# Out:
# Text(0.5, 1.0, 'Scatterplot of Total bill vs Tip')

# %% [markdown]
# # line plot

# %%
sns.lineplot(data=tips, x="size", y="total_bill",hue='sex',markers="o")
plt.title("Lineplot of Total Bill vs Size")
# Out:
# Text(0.5, 1.0, 'Lineplot of Total Bill vs Size')

# %%
sns.lineplot(data=tips, x= 'size', y='total_bill', hue='sex',ci=None, markers='o')
plt.title("Lineplot of Total Bill vs Size")
plt.show()

# %% [markdown]
# # 3 Bar plot

# %%
sns.barplot(data=tips,x="day",y="total_bill",hue="sex",palette="muted")
plt.title("Barplot of Total Bill by day")
# Out:
# Text(0.5, 1.0, 'Barplot of Total Bill by day')

# %%
tips.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %% [markdown]
# # 4 Box plot

# %%
sns.boxplot(data=tips, x='day',y='tip',hue="smoker",palette='deep')
plt.title("Boxplot of tips by day and smoker status")
# Out:
# Text(0.5, 1.0, 'Boxplot of tips by day and smoker status')

# %% [markdown]
# # 5. violin plot

# %%
sns.violinplot(data=tips, x='day', y='total_bill', hue='time', split=True, palette='pastel')
plt.title("Violin Plot of Total Bill by Day and Time")  
plt.show()

# %% [markdown]
# # 6. count plot

# %%
sns.countplot(data=tips,x='day',hue='smoker',palette="dark")
plt.title("Countplot od Days by Smoker Status")
# Out:
# Text(0.5, 1.0, 'Countplot od Days by Smoker Status')

# %% [markdown]
# # 7 Regression plot

# %%
sns.regplot(data=tips, x='total_bill', y='tip', scatter_kws={'s':50}, line_kws={'color':'red'})
plt.title("Regression Plot of Total Bill vs Tip")
# Out:
# Text(0.5, 1.0, 'Regression Plot of Total Bill vs Tip')

# %% [markdown]
# # 8 histogram

# %%
sns.histplot(data=tips,x='total_bill',bins=20, kde=True,color='green')
plt.title("Histogram of Total Bill with KDE")
# Out:
# Text(0.5, 1.0, 'Histogram of Total Bill with KDE')

# %% [markdown]
# # 9.pairplot

# %%
sns.pairplot(data=tips,hue='sex',vars=["total_bill",'tip','size'],palette="husl")
plt.suptitle("Pair plot: numerical variables by gender",y=1.02)
# Out:
# Text(0.5, 1.02, 'Pair plot: numerical variables by gender')

# %% [markdown]
# # 10 catplot

# %%
sns.catplot(tips,x='day',y='tip',hue='sex',kind='point',palette='bright')
plt.title('Catplot(points): Tips by day and gender ')
# Out:
# Text(0.5, 1.0, 'Catplot(points): Tips by day and gender ')

# %% [markdown]
# # 11 joint plot

# %%
sns.jointplot(data=tips, x='total_bill',y='tip',hue='sex',kind='scatter',color='blue',palette='coolwarm')
plt.suptitle('Joint plot : Total Bill VS Tip')
# Out:
# Text(0.5, 0.98, 'Joint plot : Total Bill VS Tip')

# %%
sns.jointplot(data=tips, x='total_bill', y='tip', kind='scatter', hue='smoker',  palette='coolwarm')
plt.suptitle("Jointplot: Total Bill vs Tip", y=1.02)
plt.show()

# %% [markdown]
# # 12 Facetgrid

# %%
g = sns.FacetGrid(tips, col='time', row='smoker', margin_titles=True).map(sns.histplot, 'total_bill', bins=20, kde=True).add_legend()
g

# %% [markdown]
# # 13 strip plot

# %%
sns.stripplot(tips, x='day',y='tip',hue='sex',palette='Set1',jitter=True)
plt.title('Strip plot: Tips by data and gender"')
# Out:
# Text(0.5, 1.0, 'Strip plot: Tips by data and gender"')

# %% [markdown]
# # 14 KDE plot

# %%
sns.kdeplot(tips,x='total_bill',hue='sex',fill=True,palette='tab10')
plt.title("kde plot:Total bill density by gender")
# Out:
# Text(0.5, 1.0, 'kde plot:Total bill density by gender')
